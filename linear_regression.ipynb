# %% [markdown]
# <a href="https://colab.research.google.com/github/shaeera-shadha/ctrl_alt_defeat/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data (X and Y)
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Independent variable
y = np.array([2, 4, 5, 4, 5])  # Dependent variable

# Create and train the model
model = LinearRegression()
model.fit(x, y)

# Get slope and intercept
slope = model.coef_[0]
intercept = model.intercept_

# Predict Y values
y_pred = model.predict(x)

# Print results
print(f"Slope: {slope:.2f}")
print(f"Intercept: {intercept:.2f}")

# Plot data and regression line
plt.scatter(x, y, color='blue', label="Actual Data")
plt.plot(x, y_pred, color='red', label="Regression Line")

plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
# Out:
# Slope: 0.60
# Intercept: 2.20
